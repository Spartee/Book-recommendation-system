# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings; warnings.simplefilter('ignore')

# %%
# Build a full dataset of all datasets in the input dir with pandas
from pathlib import Path
full_dataset = pd.concat([pd.read_csv(str(x.resolve())) for x in Path("/kaggle/input/goodreads-book-datasets-10m/").glob("*k.csv")])
full_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1850310 entries, 0 to 43621
# Data columns (total 21 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   RatingDist4            object
#  1   RatingDist1            object
#  2   ISBN                   object
#  3   Authors                object
#  4   Id                     int64
#  5   pagesNumber            float64
#  6   Language               object
#  7   RatingDist3            object
#  8   Name                   object
#  9   PublishYear            int64
#  10  CountsOfReview         int64
#  11  RatingDist5            object
#  12  PublishMonth           int64
#  13  RatingDist2            object
#  14  PublishDay             int64
#  15  RatingDistTotal        object
#  16  Rating                 float64
#  17  Publisher              object
#  18  Description            object
#  19  Count of text reviews  float64
#  20  PagesNumber            float64
# dtypes: float64(4), int64(5), object(12)
# memory usage: 310.6+ MB

# %%
# Each rating column looks like x:432411 where the x is the star count.
# since this is redundant and ruins the data typing, we can take it out.
# turn the RatingDist columns into itegers by splitting of the first part.
for i in range(1,6):
    full_dataset['RatingDist'+str(i)] = full_dataset['RatingDist'+str(i)].str.split(':').str[1]
full_dataset["RatingDistTotal"] = full_dataset["RatingDistTotal"].str.split(':').str[1]

to_convert = ["RatingDist1", "RatingDist2", "RatingDist3", "RatingDist4", "RatingDist5", "RatingDistTotal"]
for col in to_convert:
    full_dataset[col] = full_dataset[col].astype(int)

full_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1850310 entries, 0 to 43621
# Data columns (total 21 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   RatingDist4            int64
#  1   RatingDist1            int64
#  2   ISBN                   object
#  3   Authors                object
#  4   Id                     int64
#  5   pagesNumber            float64
#  6   Language               object
#  7   RatingDist3            int64
#  8   Name                   object
#  9   PublishYear            int64
#  10  CountsOfReview         int64
#  11  RatingDist5            int64
#  12  PublishMonth           int64
#  13  RatingDist2            int64
#  14  PublishDay             int64
#  15  RatingDistTotal        int64
#  16  Rating                 float64
#  17  Publisher              object
#  18  Description            object
#  19  Count of text reviews  float64
#  20  PagesNumber            float64
# dtypes: float64(4), int64(11), object(6)
# memory usage: 310.6+ MB

# %%
# Make our dataset smaller in memory Thanks to : https://www.kaggle.com/aantonova/some-new-risk-and-clusters-feature
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

reduce_mem_usage(full_dataset)
# Out:
# Mem. usage decreased to 187.05 Mb (39.8% reduction)
#        RatingDist4  RatingDist1        ISBN              Authors       Id  \
# 0               10            2  080959577X      Mrs. Henry Wood   300002
# 1                1            0  1402158718      Mrs. Henry Wood   300005
# 2               23            0  1598180339      Mrs. Henry Wood   300007
# 3             5969          278  0613607406           Celia Rees   300008
# 4               15            2  0859537803          Arden Druce   300009
# ...            ...          ...         ...                  ...      ...
# 43617            0            0  0199184836           Liz  Miles  1299980
# 43618            1            0  0841913587  Colbert Nepaulsingh  1299992
# 43619            9            0  0876044909       Michael Mirdad  1299994
# 43620          104            3  0824068378     William Faulkner  1299998
# 43621            0            0  0787644714    Thomas L. McHaney  1299999
#
#        pagesNumber Language  RatingDist3  \
# 0            487.0      eng            5
# 1            310.0      NaN            1
# 2            380.0      NaN           11
# 3            261.0      NaN         4461
# 4             32.0      NaN           14
# ...            ...      ...          ...
# 43617         32.0      NaN            0
# 43618        149.0      NaN            1
# 43619        109.0      NaN            2
# 43620        297.0      NaN           44
# 43621        218.0      NaN            0
#
#                                                     Name  PublishYear  ...  \
# 0                                          The Channings         2004  ...
# 1                William Allair; Or, Running Away To Sea         2005  ...
# 2                                          Anne Hereford         2006  ...
# 3                                            Witch Child         2002  ...
# 4                          Witch, Witch Come To My Party         1991  ...
# ...                                                  ...          ...  ...
# 43617  Oxford Reading Tree: Stage 16A: TreeTops Class...         2006  ...
# 43618              Apples of Gold in Filigress of Silver         1995  ...
# 43619        The Seven Initiations of the Spiritual Path         2004  ...
# 43620                                Unpublished Stories         1987  ...
# 43621  Literary Topics, Volume 6: The Southern Renasc...         2001  ...
#
#        RatingDist5  PublishMonth  RatingDist2  PublishDay  RatingDistTotal  \
# 0               13             1            4           7               34
# 1                0            30            0          11                2
# 2               17             1            1          10               52
# 3             4238             1         1122           4            16068
# 4               37             1            2          10               70
# ...            ...           ...          ...         ...              ...
# 43617            0            28            0           9                0
# 43618            0             1            0           1                2
# 43619           11             1            1           3               23
# 43620          116             1            6          11              273
# 43621            0            27            0           3                0
#
#          Rating                                          Publisher  \
# 0      3.820312                                     Wildside Press
# 1      3.500000                          Adamant Media Corporation
# 2      4.078125                                            Aegypan
# 3      3.789062                                   Turtleback Books
# 4      4.191406                         Child's Play International
# ...         ...                                                ...
# 43617  0.000000                            Oxford University Press
# 43618  3.500000                          Holmes & Meier Publishers
# 43619  4.300781  A.R.E. Press (Association of Research & Enligh...
# 43620  4.191406                                    Facsimiles-Garl
# 43621  0.000000                                                NaN
#
#                                              Description  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 43617                                                NaN
# 43618                                                NaN
# 43619  - Foreword by Dr. Michael Abrams, author of th...
# 43620  This invaluable volume, which has been republi...
# 43621  Gale Study Guides to Great Literature are a un...
#
#       Count of text reviews  PagesNumber
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# ...                     ...          ...
# 43617                   0.0          NaN
# 43618                   0.0          NaN
# 43619                   2.0          NaN
# 43620                   0.0          NaN
# 43621                   0.0          NaN
#
# [1850310 rows x 21 columns]

# %%
# look at the dates
full_dataset[["PublishYear", "PublishMonth", "PublishDay"]].describe()
# Out:
#         PublishYear  PublishMonth    PublishDay
# count  1.850310e+06  1.850310e+06  1.850310e+06
# mean   1.997841e+03  7.700550e+00  7.987211e+00
# std    8.789461e+01  7.756940e+00  8.431777e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.993000e+03  1.000000e+00  1.000000e+00
# 50%    2.000000e+03  6.000000e+00  5.000000e+00
# 75%    2.005000e+03  1.100000e+01  1.100000e+01
# max    6.553500e+04  3.100000e+01  3.100000e+01

# %%
# so something is seriously wrong with publish month... 31st month??? huh? lets drop it.
full_dataset.drop(columns=["PublishMonth"], inplace=True)

# %%
# take a look at the years in the dataset
full_dataset[(full_dataset['PublishYear'] < 1400) | (full_dataset['PublishYear'] > 2020)]
# Out:
#         RatingDist4  RatingDist1        ISBN            Authors       Id  \
# 24627            22            3  0785379185         John Kurtz   343405
# 28788            47            5  0373292813      Margo Maguire   350490
# 816              85            3  0076074000   Charlotte Brontë  3001922
# 5032              0            0  0521614813     Alexander Sens  3012346
# 30547          2773           54  3442310148   Michael Robotham  3080023
# ...             ...          ...         ...                ...      ...
# 102144           13            3  1592122515     L. Ron Hubbard  4310347
# 160768            0            0  9640005126    نائوم لایکوفسکی  4488314
# 222257            3            0  0520062418  Daniel D. Arnheim  4670608
# 278158            0            0         NaN  حمیدرضا جلائی‌پور  4838633
# 30825             0            0  0814782957             Murari  1271191
#
#         pagesNumber Language  RatingDist3  \
# 24627          24.0      eng           19
# 28788         304.0      eng           46
# 816             NaN      NaN           41
# 5032            NaN      NaN            0
# 30547           NaN      ger         1635
# ...             ...      ...          ...
# 102144          NaN      NaN            7
# 160768          NaN      NaN            1
# 222257          NaN      NaN            0
# 278158          NaN      NaN            0
# 30825         638.0      NaN            0
#
#                                                 Name  PublishYear  \
# 24627              Disney Princesses (Look and Find)          200
# 28788       The Virtuous Knight (Medieval Brides #4)          299
# 816     Jane Eyre, Shirley, Villette & The Professor         3006
# 5032               Hellenistic Epigrams: A Selection         2021
# 30547                Amnesie (Joseph O'Loughlin, #2)        20016
# ...                                              ...          ...
# 102144                           Twenty Fathoms Down         2103
# 160768                                  قدر يک لبخند         1387
# 222257                        The Power of he Center        65535
# 278158                         فراز و فرود جنبش کردی         1385
# 30825      Rama Beyond Price (Clay Sanskrit Library)        20067
#
#         CountsOfReview  RatingDist5  RatingDist2  PublishDay  RatingDistTotal  \
# 24627                9           23            7          12               74
# 28788               12           48           14          11              160
# 816                  3          158            8          25              295
# 5032                 0            0            0          31                0
# 30547                3         1523          309          21             6294
# ...                ...          ...          ...         ...              ...
# 102144               3            6            7          22               36
# 160768               2            3            0           6                4
# 222257               1            0            0          15                3
# 278158               0            0            0          11                0
# 30825                0            0            0           1                0
#
#           Rating                   Publisher  \
# 24627   3.740234  Publications International
# 28788   3.740234        Harlequin Historical
# 816     4.308594            Barnes and Noble
# 5032    0.000000  Cambridge University Press
# 30547   3.859375             Goldmann Verlag
# ...          ...                         ...
# 102144  3.330078                Galaxy Press
# 160768  4.500000                    اميرکبير
# 222257  4.000000                         NaN
# 278158  0.000000                     لوح فکر
# 30825   0.000000               Clay Sanskrit
#
#                                               Description  \
# 24627                                                 NaN
# 28788                                                 NaN
# 816                       In her fiction, Charlotte Bront
# 5032    Greek "literary" epigrams constitute one of th...
# 30547   Mit Schusswunden im Bein, einem abgeschossenen...
# ...                                                   ...
# 102144  <b>As daring and defiant as Kirk Douglas journ...
# 160768                                                NaN
# 222257  Using a wealth of examples, Arnheim considers ...
# 278158                                                NaN
# 30825   Rama Beyond Price, a dramatized remake of the ...
#
#         Count of text reviews  PagesNumber
# 24627                     NaN          NaN
# 28788                     NaN          NaN
# 816                       NaN       1167.0
# 5032                      NaN        320.0
# 30547                     NaN        448.0
# ...                       ...          ...
# 102144                    NaN        136.0
# 160768                    NaN        382.0
# 222257                    NaN        256.0
# 278158                    NaN        236.0
# 30825                     0.0          NaN
#
# [95 rows x 20 columns]

# %%
# pretty sure 3006 hasn't happenned yet, so let's filter those out
full_dataset = full_dataset[full_dataset['PublishYear'] > 1400]
full_dataset = full_dataset[full_dataset['PublishYear'] < 2022]
full_dataset.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1850262 entries, 0 to 43621
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   RatingDist4            1850262 non-null  int32
#  1   RatingDist1            1850262 non-null  int32
#  2   ISBN                   1844343 non-null  object
#  3   Authors                1850262 non-null  object
#  4   Id                     1850262 non-null  int32
#  5   pagesNumber            835059 non-null   float32
#  6   Language               251797 non-null   object
#  7   RatingDist3            1850262 non-null  int32
#  8   Name                   1850262 non-null  object
#  9   PublishYear            1850262 non-null  int32
#  10  CountsOfReview         1850262 non-null  int32
#  11  RatingDist5            1850262 non-null  int32
#  12  RatingDist2            1850262 non-null  int32
#  13  PublishDay             1850262 non-null  int8
#  14  RatingDistTotal        1850262 non-null  int32
#  15  Rating                 1850262 non-null  float16
#  16  Publisher              1832442 non-null  object
#  17  Description            1171155 non-null  object
#  18  Count of text reviews  409687 non-null   float16
#  19  PagesNumber            1015203 non-null  float32
# dtypes: float16(2), float32(2), int32(9), int8(1), object(6)
# memory usage: 185.3+ MB

# %%
print(full_dataset.Language.unique())
full_dataset["Language"].describe()
# Out:
# ['eng' nan 'en-CA' 'en-US' 'spa' 'ger' 'fre' 'ypk' 'en-GB' 'grc' 'mul'
#  'por' 'ita' 'tur' 'sco' 'frs' 'nl' 'jpn' 'lao' 'rus' 'zho' 'kor' 'ang'
#  'hye' 'raj' 'fil' 'frm' 'tgl' 'gre' 'lat' 'per' 'swe' 'wel' 'slv' 'epo'
#  'msa' 'ara' 'ind' 'dan' 'pol' 'nav' 'tli' 'san' 'srp' 'afr' 'chi' 'som'
#  'sqi' 'cat' 'gle' 'rar' 'heb' 'rum' 'vie' 'hmn' 'tib' 'nor' 'yid' 'gmh'
#  'nob' 'goh' 'jav' 'mri' 'che' 'sna' 'nld' 'ben' 'elx' 'tel' 'scr' 'aze'
#  'bul' 'glg' '--' 'enm' 'fin' 'gla' 'mal' 'hin' 'est' 'myv' 'zul' 'cze'
#  'tlh' 'nub' 'eus' 'ave' 'mga' 'fan' 'hun' 'cre' 'bos' 'tha' 'urd' 'wak'
#  'guj' 'chp' 'tam' 'fro' 'myn' 'lav' 'cop' 'ada' 'zap' 'aus' 'kur' 'nep'
#  'nai' 'lit' 'nqo' 'tah' 'slo' 'mar' 'isl' 'mah' 'kan' 'non' 'ira' 'ssw'
#  'mis' 'zun' 'dum' 'gem' 'haw' 'sam']
# count     251797
# unique       124
# top          eng
# freq      180327
# Name: Language, dtype: object

# %%
# so it's predominatly english books, but lets change en-GB and en-CA to english
full_dataset["Language"].replace(["en-GB", "en-CA", "en-US"], "eng", inplace=True)
print(full_dataset.Language.unique())
full_dataset["Language"].describe()
# Out:
# ['eng' nan 'spa' 'ger' 'fre' 'ypk' 'grc' 'mul' 'por' 'ita' 'tur' 'sco'
#  'frs' 'nl' 'jpn' 'lao' 'rus' 'zho' 'kor' 'ang' 'hye' 'raj' 'fil' 'frm'
#  'tgl' 'gre' 'lat' 'per' 'swe' 'wel' 'slv' 'epo' 'msa' 'ara' 'ind' 'dan'
#  'pol' 'nav' 'tli' 'san' 'srp' 'afr' 'chi' 'som' 'sqi' 'cat' 'gle' 'rar'
#  'heb' 'rum' 'vie' 'hmn' 'tib' 'nor' 'yid' 'gmh' 'nob' 'goh' 'jav' 'mri'
#  'che' 'sna' 'nld' 'ben' 'elx' 'tel' 'scr' 'aze' 'bul' 'glg' '--' 'enm'
#  'fin' 'gla' 'mal' 'hin' 'est' 'myv' 'zul' 'cze' 'tlh' 'nub' 'eus' 'ave'
#  'mga' 'fan' 'hun' 'cre' 'bos' 'tha' 'urd' 'wak' 'guj' 'chp' 'tam' 'fro'
#  'myn' 'lav' 'cop' 'ada' 'zap' 'aus' 'kur' 'nep' 'nai' 'lit' 'nqo' 'tah'
#  'slo' 'mar' 'isl' 'mah' 'kan' 'non' 'ira' 'ssw' 'mis' 'zun' 'dum' 'gem'
#  'haw' 'sam']
# count     251797
# unique       121
# top          eng
# freq      209661
# Name: Language, dtype: object

# %%
# we will then drop the rest of the languages as our simple rec-sys will be english only for now.
full_dataset = full_dataset[full_dataset["Language"] == "eng"]
full_dataset.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209661 entries, 0 to 43614
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   RatingDist4            209661 non-null  int32
#  1   RatingDist1            209661 non-null  int32
#  2   ISBN                   207684 non-null  object
#  3   Authors                209661 non-null  object
#  4   Id                     209661 non-null  int32
#  5   pagesNumber            141801 non-null  float32
#  6   Language               209661 non-null  object
#  7   RatingDist3            209661 non-null  int32
#  8   Name                   209661 non-null  object
#  9   PublishYear            209661 non-null  int32
#  10  CountsOfReview         209661 non-null  int32
#  11  RatingDist5            209661 non-null  int32
#  12  RatingDist2            209661 non-null  int32
#  13  PublishDay             209661 non-null  int8
#  14  RatingDistTotal        209661 non-null  int32
#  15  Rating                 209661 non-null  float16
#  16  Publisher              206783 non-null  object
#  17  Description            122157 non-null  object
#  18  Count of text reviews  58472 non-null   float16
#  19  PagesNumber            67860 non-null   float32
# dtypes: float16(2), float32(2), int32(9), int8(1), object(6)
# memory usage: 21.0+ MB

# %%
# lets check out deplicates
full_dataset.Name.value_counts()[:20]
# Out:
# Romeo and Juliet                                              17
# The Call of the Wild                                          14
# To the Lighthouse                                             13
# Beloved                                                       13
# A Christmas Carol                                             13
# Gulliver's Travels                                            13
# The Trial                                                     12
# The Jungle Book                                               12
# The Collected Stories                                         12
# The Brothers Karamazov                                        12
# Bleak House                                                   12
# Harry Potter and the Chamber of Secrets (Harry Potter, #2)    11
# To Kill a Mockingbird                                         11
# The Complete Works                                            11
# Flatland: A Romance of Many Dimensions                        11
# Aesop's Fables                                                11
# The Great Gatsby                                              11
# The Amber Spyglass (His Dark Materials, #3)                   11
# The Idiot                                                     11
# Heart of Darkness                                             11
# Name: Name, dtype: int64

# %%
# so there are alot of duplicate listings here, lets drop all the books by the excat same name and authors
# this should remove books that were re-pulished by the same author and name but possibly by a different publisher
full_dataset.drop_duplicates(subset=["Authors", "Name"], inplace=True)
full_dataset.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187249 entries, 0 to 43614
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   RatingDist4            187249 non-null  int32
#  1   RatingDist1            187249 non-null  int32
#  2   ISBN                   185638 non-null  object
#  3   Authors                187249 non-null  object
#  4   Id                     187249 non-null  int32
#  5   pagesNumber            125086 non-null  float32
#  6   Language               187249 non-null  object
#  7   RatingDist3            187249 non-null  int32
#  8   Name                   187249 non-null  object
#  9   PublishYear            187249 non-null  int32
#  10  CountsOfReview         187249 non-null  int32
#  11  RatingDist5            187249 non-null  int32
#  12  RatingDist2            187249 non-null  int32
#  13  PublishDay             187249 non-null  int8
#  14  RatingDistTotal        187249 non-null  int32
#  15  Rating                 187249 non-null  float16
#  16  Publisher              184576 non-null  object
#  17  Description            109168 non-null  object
#  18  Count of text reviews  51580 non-null   float16
#  19  PagesNumber            62163 non-null   float32
# dtypes: float16(2), float32(2), int32(9), int8(1), object(6)
# memory usage: 18.8+ MB

# %%
full_dataset.Name.value_counts()[:20]
# Out:
# The Collected Stories        11
# Selected Writings             9
# The Arabian Nights            7
# Collected Poems               7
# The Major Works               7
# The Emperor's New Clothes     7
# Selected Poems                7
# Paradise                      6
# The Collected Poems           6
# Collected Stories             6
# The Snow Queen                6
# The Bremen Town Musicians     6
# The Complete Works            6
# Political Writings            5
# When I Grow Up                5
# Aesop's Fables                5
# Poems                         5
# Collected Short Stories       5
# Echoes                        5
# Hunter's Moon                 5
# Name: Name, dtype: int64

# %%
full_dataset.head()
# Out:
#     RatingDist4  RatingDist1        ISBN            Authors      Id  \
# 0            10            2  080959577X    Mrs. Henry Wood  300002
# 7          1861           92  0763621838         Celia Rees  300017
# 20            0            0  0689843798     Annie Auerbach  300036
# 24           70            0  0571207375  Jonathan Sumption  300041
# 26         1588           73  1416525033      Karen Hawkins  300043
#
#     pagesNumber Language  RatingDist3  \
# 0         487.0      eng            5
# 7         352.0      eng         1700
# 20         12.0      eng            2
# 24        655.0      eng           14
# 26        313.0      eng         1146
#
#                                                  Name  PublishYear  \
# 0                                       The Channings         2004
# 7                         Sorceress (Witch Child, #2)         2003
# 20                                Bob's Recycling Day         2001
# 24     Trial by Fire: The Hundred Years War, Volume 2         2001
# 26  How to Abduct a Highland Lord (MacLean Curse, #1)         2007
#
#     CountsOfReview  RatingDist5  RatingDist2  PublishDay  RatingDistTotal  \
# 0                3           13            4           7               34
# 7              200         1281          474           3             5408
# 20               1            2            0           9                4
# 24               7          111            0           8              195
# 26             222         1407          241           1             4455
#
#       Rating        Publisher Description  Count of text reviews  PagesNumber
# 0   3.820312   Wildside Press         NaN                    NaN          NaN
# 7   3.699219       Candlewick         NaN                    NaN          NaN
# 20  4.000000  Simon Spotlight         NaN                    NaN          NaN
# 24  4.500000    Faber & Faber         NaN                    NaN          NaN
# 26  3.900391     Pocket Books         NaN                    NaN          NaN

# %%
# drop some columns we won't need for now
full_dataset.drop(columns=["PagesNumber", "CountsOfReview", "Count of text reviews", "pagesNumber"], inplace=True)

# %%
# fill the empty descriptions with the names of the books
full_dataset.Description.fillna(full_dataset.Name, inplace=True)

# %%
full_dataset.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187249 entries, 0 to 43614
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   RatingDist4      187249 non-null  int32
#  1   RatingDist1      187249 non-null  int32
#  2   ISBN             185638 non-null  object
#  3   Authors          187249 non-null  object
#  4   Id               187249 non-null  int32
#  5   Language         187249 non-null  object
#  6   RatingDist3      187249 non-null  int32
#  7   Name             187249 non-null  object
#  8   PublishYear      187249 non-null  int32
#  9   RatingDist5      187249 non-null  int32
#  10  RatingDist2      187249 non-null  int32
#  11  PublishDay       187249 non-null  int8
#  12  RatingDistTotal  187249 non-null  int32
#  13  Rating           187249 non-null  float16
#  14  Publisher        184576 non-null  object
#  15  Description      187249 non-null  object
# dtypes: float16(1), int32(8), int8(1), object(6)
# memory usage: 16.3+ MB

# %%
# drop remaining columns
full_dataset.dropna(inplace=True)
full_dataset.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183031 entries, 0 to 43614
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   RatingDist4      183031 non-null  int32
#  1   RatingDist1      183031 non-null  int32
#  2   ISBN             183031 non-null  object
#  3   Authors          183031 non-null  object
#  4   Id               183031 non-null  int32
#  5   Language         183031 non-null  object
#  6   RatingDist3      183031 non-null  int32
#  7   Name             183031 non-null  object
#  8   PublishYear      183031 non-null  int32
#  9   RatingDist5      183031 non-null  int32
#  10  RatingDist2      183031 non-null  int32
#  11  PublishDay       183031 non-null  int8
#  12  RatingDistTotal  183031 non-null  int32
#  13  Rating           183031 non-null  float16
#  14  Publisher        183031 non-null  object
#  15  Description      183031 non-null  object
# dtypes: float16(1), int32(8), int8(1), object(6)
# memory usage: 15.9+ MB

# %%
# use regex to clean up the descriptions as some of them have embedded HTML tags like <br>
import re
# compile once only
CLEANR = re.compile('<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});') 

def cleanhtml(raw_html):
    cleantext = re.sub(CLEANR, '', raw_html)
    return cleantext

# %%
full_dataset["Description"] = full_dataset.Description.apply(cleanhtml)
full_dataset.Description.sample(100)
# Out:
# 27296     Neighbors were unaware of what went on behind ...
# 5142      When Perennis Felix, favorite of the Roman Emp...
# 36945             One Piece, Volume 10: OK, Let's Stand Up!
# 39721     The Interdependence Handbook is a collection o...
# 109406                                       Of God and Man
#                                 ...
# 2284                  Sherlock Holmes: A Baker Street Dozen
# 51172     Birgivi's Manual Interpreted: Complete Fiqh of...
# 34355     Invisible Lives: The Erasure of Transsexual an...
# 1968      Catherine's words help us to experience her pr...
# 46404                                          Stuck on You
# Name: Description, Length: 100, dtype: object

# %% [markdown]
# ## Simple Weighted Rating
#
# Weighted Rating (WR) = $(\frac{v}{v + q} . R) + (\frac{q}{v + q} . C)$
#
# where,
# * *v* is the number of votes for the book (total)
# * *q* is the minimum votes required to be listed in the chart
# * *R* is the average rating of all books
# * *C* is the mean vote across the entire dataset
#
# inspired by: https://www.kaggle.com/rounakbanik/movie-recommender-systems

# %%
ratings = full_dataset["Rating"]
rating_count = full_dataset["RatingDistTotal"]
MR = ratings.convert_dtypes(np.float16).mean()
print("Mean Rating (MR) accross all books: ", MR)

q = rating_count.quantile(0.98)
print("Minimum number of required ratings: ", q)
# Out:
# Mean Rating (MR) accross all books:  3.735411229433129
# Minimum number of required ratings:  48706.59999999977

# %% [markdown]
# ### Weighting Metrics
# - ``MR`` = Mean rating = 3.75 (out of 5)
# - ``q`` = minimum number of ratings required

# %%
# our weighted rating algorithm
def weighted_rating(book):
    v = book['RatingDistTotal']
    R = book['Rating']
    return (v/(v+q) * R) + (q/(q+v) * MR)

# %%
top_books = full_dataset[(full_dataset["RatingDistTotal"] >= q) & (full_dataset["Rating"] > MR)]
top_books["weighted"] = top_books.apply(weighted_rating, axis=1)
above_average = top_books.sort_values("weighted", ascending=False)
above_average.shape
# Out:
# (3340, 17)

# %%
# So clearly Harry Potter is a popular book. No surprise there.
above_average.head()
# Out:
#        RatingDist4  RatingDist1        ISBN       Authors       Id Language  \
# 9868        532119        22089  1551929767  J.K. Rowling   818056      eng
# 59051        35788         1628  0739352245  J.K. Rowling  2132220      eng
# 22521        35557         1572  074759368X  J.K. Rowling  1668766      eng
# 22520        35557         1572  0747594562  J.K. Rowling  1668764      eng
# 36205        35392         1549  0747593698  J.K. Rowling   988373      eng
#
#        RatingDist3                                               Name  \
# 9868        156299  Harry Potter and the Deathly Hallows (Harry Po...
# 59051         8335  Harry Potter Audio Collection (Harry Potter, #...
# 22521         8250        Harry Potter Boxed Set (Harry Potter, #1-7)
# 22520         8250  The Complete Harry Potter Collection Box Set (...
# 36205         8190                    Complete Harry Potter Boxed Set
#
#        PublishYear  RatingDist5  RatingDist2  PublishDay  RatingDistTotal  \
# 9868          2007      1960662        33318           7          2704487
# 59051         2007       200090         1665          17           247506
# 22521         2007       198894         1643          10           245916
# 22520         2007       198894         1643          10           245916
# 36205         2007       197903         1634          10           244668
#
#          Rating                                  Publisher  \
# 9868   4.621094  Bloomsbury Publishing Plc/Raincoast Books
# 59051  4.738281                  Listening Library (Audio)
# 22521  4.738281                                 Bloomsbury
# 22520  4.738281                                 Bloomsbury
# 36205  4.738281                      Bloomsbury Publishing
#
#                                              Description  weighted
# 9868   Harry is waiting in Privet Drive. The Order of...  4.605425
# 59051  Enjoy the complete Harry Potter series perform...  4.573378
# 22521  A fabulous opportunity to own all seven Harry ...  4.572488
# 22520  A fabulous opportunity to own all seven Harry ...  4.572488
# 36205  A fabulous opportunity to own all seven Harry ...  4.571783

# %%
# lets take a random sample
above_average.sample(10).sort_values(by="weighted", ascending=False)
# Out:
#        RatingDist4  RatingDist1        ISBN             Authors       Id  \
# 33760        77854         1340  0099428512      Diana Gabaldon   864696
# 43191        29923         1519  0892640308             Lao Tzu   276698
# 26702        23449          787  0679643249      Michael Shaara    44469
# 23293        26437         1125  0141024917  Fyodor Dostoyevsky   843006
# 18503       107052         5919  0061020710     Terry Pratchett   533613
# 36853        16338         1159  0671582089     Anthony Robbins  1285192
# 17206        17838          797  0312851820        Vernor Vinge   940486
# 14794        34518          972  0141185414        John Wyndham   826846
# 7970         81669        10630  0441000681      William Gibson   313982
# 35172        40111         2750  0440242398     Sophie Kinsella  3092108
#
#       Language  RatingDist3  \
# 33760      eng        27570
# 43191      eng        14333
# 26702      eng         8628
# 23293      eng        11862
# 18503      eng        65031
# 36853      eng         8933
# 17206      eng         7968
# 14794      eng        18352
# 7970       eng        49821
# 35172      eng        33804
#
#                                                     Name  PublishYear  \
# 33760                                            Voyager         1995
# 43191  A Translation of Lao-tzu's Tao Te Ching and Wa...         1977
# 26702  The Killer Angels: A Novel of the Civil War (T...         2004
# 23293                             Notes from Underground         2006
# 18503                 The Color of Magic (Discworld, #1)         2000
# 36853                            Awaken The Giant Within         2000
# 17206                               A Fire Upon the Deep         1992
# 14794                            The Day of the Triffids         2001
# 7970                    Neuromancer (Sprawl Trilogy, #1)         1994
# 35172                                Shopaholic and Baby         2009
#
#        RatingDist5  RatingDist2  PublishDay  RatingDistTotal    Rating  \
# 33760       135066         4110           8           245940  4.390625
# 43191        58136         3365           1           107276  4.300781
# 26702        38309         1948          12            73121  4.320312
# 23293        33148         2754          10            75326  4.160156
# 18503       109875        15612           2           303489  3.990234
# 36853        25414         2391           2            54235  4.148438
# 17206        21400         2087           4            50090  4.140625
# 14794        29634         3484           2            86960  4.019531
# 7970         91835        18238           7           252193  3.900391
# 35172        34521         8611          28           119797  3.789062
#
#                         Publisher  \
# 33760             Arrow Books Ltd
# 43191  Center for Chinese Studies
# 26702              Modern Library
# 23293           Penguin Group(CA)
# 18503                 HarperTorch
# 36853       Simon  Schuster Audio
# 17206                         Tor
# 14794     Penguin Modern Classics
# 7970                Ace Hardcover
# 35172     Dell Publishing Company
#
#                                              Description  weighted
# 33760  An alternate cover for this isbn can be found ...  4.282315
# 43191  A Translation of Lao-tzu's Tao Te Ching and Wa...  4.124241
# 26702  The Killer Angels: A Novel of the Civil War (T...  4.086469
# 23293  How far would you go to escape the real world?...  3.993362
# 18503                 The Color of Magic (Discworld, #1)  3.954994
# 36853  Wake up and take control of your life! From th...  3.953015
# 17206  Vernor Vinge has shown, in books like True Nam...  3.940855
# 14794  When Bill Masen wakes up blindfolded in hospit...  3.917527
# 7970                    Neuromancer (Sprawl Trilogy, #1)  3.873685
# 35172  Becky’s life is blooming! She’s working at Lon...  3.773554

# %% [markdown]
# # Content Based Recommendations
#
# The goal here is to see if we can recommend books based on the similarity in the descriptions between books.

# %%
from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# sample 20000 points so we don't hit kaggle's memory limit
#samples = full_dataset(20000)

samples = full_dataset[10000:30000] # use if you want the same books to be predicted on

# %%
tf = TfidfVectorizer(analyzer='word',
                     ngram_range=(1, 2),
                     min_df=0,
                     stop_words='english')
tfidf_matrix = tf.fit_transform(samples['Description'])

# %% [markdown]
# #### Cosine Similarity
#
# I will be using the Cosine Similarity to calculate a numeric quantity that denotes the similarity between two books. Mathematically, it is defined as follows:
#
# $cosine(x,y) = \frac{x. y^\intercal}{||x||.||y||} $
#
# Since we have used the TF-IDF Vectorizer, calculating the Dot Product will directly give us the Cosine Similarity Score. Therefore, we will use sklearn's **linear_kernel** instead of cosine_similarities since it is much faster.

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
# write function to get recommendations based on cosine similarity
samples = samples.reset_index()
titles = samples[['Name', 'Authors', 'PublishYear', 'Publisher']]
indices = pd.Series(samples.index, index=samples['Name'])

# %%
def get_content_recommendations(title):
    try:
        # handle case in which book by same title is in dataset
        idx = indices[title][0]
    except IndexError:
        idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:15]
    book_indices = [i[0] for i in sim_scores]
    return titles.iloc[book_indices]

# %%
index = 17136
title = samples.iloc[index].Name
desc = samples.iloc[index].Description
author = samples.iloc[index].Authors
year = samples.iloc[index].PublishYear
print("Title:", title, "\nDescription:", desc, "\nAuthor:", author, "\nYear:", year)
# Out:
# Title: Mathematics Made Simple
# Description: Brushing up on math has never been easier!Just about everyone can use some extra help improving or remembering basic math skills. Finally, all the information you need to master the basics, once and for all, is at your fingertips. Featuring several overviews of a multitude of mathematical concepts, as well as detailed learning plans, Mathematics Made Simple presents the information you need in clear, concise lessons that make math fun to study. Easy-to-use features include:* complete coverage of fractions, decimals, percents, algebra, linear equations, graphs, probability, geometry, and trigonometry* step-by-step solutions to every problem *multiple choice tests to help you monitor your progress * a final, comprehensive test that makes it easy to pinpoint your strengths and target areas that need work* glossaries of relevant mathematical terms* sidebars that introduce real-life applications of mathematical principlesVoid of lengthy explanations and difficult computations, Mathematics Made Simple will banish your math anxiety forever.
# Author: Thomas Cusick
# Year: 2003

# %%
get_content_recommendations(title)
# Out:
#                                                     Name  \
# 3828   Kaplan Math Power: Essential Guide for Math Su...
# 8592                                   Mouse Moves House
# 13757  Introductory Mathematical Analysis for Busines...
# 13211            The Complete Book of Math, Grades 3 - 4
# 6807                              Spectrum Math: Grade 2
# 13389                                              Games
# 6966                                        Walk on Maps
# 2386   Math For All Seasons: Mind-Stretching Math Rid...
# 13597                   Math: Grade 6 (Skill Sharpeners)
# 19323                 Give Me Half! (Mathstart: Level 2)
# 2705     CBEST: California Basic Educational Skills Test
# 7737       50 Mathematical Ideas You Really Need to Know
# 15085                Life of Fred: Decimals and Percents
# 8860   Habitats, Grades 1-3 (Science Works for Kids S...
#
#                              Authors  PublishYear  \
# 3828                  Robert Stanton         2001
# 8592                   Nick Sharratt         2000
# 13757        Ernest F. Haeussler Jr.         2007
# 13211  American Education Publishing         2000
# 6807            Thomas      Richards         2002
# 13389                   Ivan Bulloch         2002
# 6966                    Mel Campbell         2006
# 2386                       Greg Tang         2002
# 13597                 Jo Ellen Moore         2005
# 19323               Stuart J. Murphy         1996
# 2705                 Kathryn Henkins         2008
# 7737                     Tony Crilly         2007
# 15085             Stanley F. Schmidt         2007
# 8860                  Jo Ellen Moore         1998
#
#                               Publisher
# 3828                             Kaplan
# 8592                         Candlewick
# 13757                           Pearson
# 13211     American Education Publishing
# 6807        Frank Schaffer Publications
# 13389                 Cooper Square Pub
# 6966           Rourke Educational Media
# 2386                   Scholastic Press
# 13597  Evan-Moor Educational Publishers
# 19323                  Turtleback Books
# 2705         Barrons Educational Series
# 7737                            Quercus
# 15085              Polka Dot Publishing
# 8860   Evan-Moor Educational Publishers

# %%
index = 18457
title = samples.iloc[index].Name
desc = samples.iloc[index].Description
author = samples.iloc[index].Authors
year = samples.iloc[index].PublishYear
print("Title:", title, "\nDescription:", desc, "\nAuthor:", author, "\nYear:", year)
# Out:
# Title: Superman/Batman, Vol. 7: The Search for Kryptonite
# Description: From Michael Green and Mike Johnson, two of the writers of the hit NBC TV series Heroes, comes this fast-paced new volume in the SUPERMAN/BATMAN series.The Man of Steel and the Dark Knight have decided that they must undertake the impossible task of recovering all the Kryptonite on Earth. But there are plenty of roadblocks in the way, as they realize that not everyone's willing to hand over the deadly substance. And one of those who's not ready to cooperate is none other than their fellow Justice League member, Aquaman.Collecting SUPERMAN/BATMAN #44-49.
# Author: Michael  Green
# Year: 2008

# %%
get_content_recommendations(title)
# Out:
#                                                     Name             Authors  \
# 14085             World's Finest Comics Archives, Vol. 2         Dick Sprang
# 10437                     The Supergirl Archives, Vol. 1        Jerry Siegel
# 11748                    Batman: The Dark Knight Returns        Frank Miller
# 8080                            Batman and Other Animals   Linda M. Jennings
# 2821                                 Out of Their League       Dave Meggyesy
# 16194                                       JLA/Avengers         Kurt Busiek
# 17056                              Batman: Harvest Breed        George Pratt
# 14081  JLA: Exterminators (Justice League of America,...  Christopher Golden
# 11344       Justice League of America, Vol. 4: Sanctuary     Dwayne McDuffie
# 9712   Age of TV Heroes: The Live-Action Adventures o...        Jason Hofius
# 18201                                 Superman: Brainiac         Geoff Johns
# 11345               Justice League International, Vol. 3        Keith Giffen
# 15515                  Superman: The Death of Clark Kent         Dan Jurgens
# 6019    Justice League Of America Vol. 1: Tornado's Path        Brad Meltzer
#
#        PublishYear                 Publisher
# 14085         2002                 DC Comics
# 10437         2001                 DC Comics
# 11748         2008                Paw Prints
# 8080          1992  Blackie Children's Books
# 2821          1971         Paperback Library
# 16194         2008                 DC Comics
# 17056         2000                 DC Comics
# 14081         2008             Graphic Audio
# 11344         2009                 DC Comics
# 9712          2010    Two Morrows Publishing
# 18201         2009                 DC Comics
# 11345         2008                 DC Comics
# 15515         1997                     Titan
# 6019          2008                 DC Comics

# %%
index = 10984
title = samples.iloc[index].Name
desc = samples.iloc[index].Description
author = samples.iloc[index].Authors
year = samples.iloc[index].PublishYear
print("Title:", title, "\nDescription:", desc, "\nAuthor:", author, "\nYear:", year)
# Out:
# Title: The Grave Tattoo
# Description: From bestselling author Val McDermid comes a modern thriller about an ancient murder set on the high seas…After summer rains uncover a corpse bearing tattoos like those of eighteenth-century seafarers, many residents of the English Lake District can’t help but wonder whether it’s the body of one of the town’s most legendary fugitives.Scholar and native Lakelander Jane Gresham feels compelled to finally discover the truth about the myths and buried secrets rooted in her hometown. What she never expected was to find herself at the heart of a 200-year-old mystery that still has the power to put lives on the line. And with each new lead she pursues, death follows hard on her heels….
# Author: Val McDermid
# Year: 2008

# %%
get_content_recommendations(title)
# Out:
#                                                     Name  \
# 16117                                       Woman in Red
# 14     The Norton Anthology of English Literature, Vo...
# 2606   Japanese High Seas Fleet (Ballantine's Illustr...
# 16607                                         Death Drop
# 6444                     Crack Down (Kate Brannigan, #3)
# 12249  Red Navy at Sea: Soviet Naval Operations on th...
# 2615                                    He Saves the Day
# 8865   The Harvest of the Hills: Rural Life in Northe...
# 9578   Ancient Israel Myths & Legends 3 in 1 (Myths a...
# 16210                                    Dead Not Buried
# 2121   Ships And Seafarers: Pupil Book (Heinemann Our...
# 13604                                     Abuse of Power
# 9579   Myths and Legends of Ancient Israel Volume 1 (...
# 14230  Beneath The Bleeding (Tony Hill & Carol Jordan...
#
#                         Authors  PublishYear  \
# 16117             Eileen Goudge         2008
# 14                  M.H. Abrams         2005
# 2606             Richard Humble         1973
# 16607                 B.M. Gill         1980
# 6444               Val McDermid         2002
# 12249           Bruce W. Watson         1982
# 2615              Marsha Hayles         2002
# 8865     Angus J. L. Winchester         2000
# 9578   Angelo Solomon Rappoport         1988
# 16210             Martin Beales         1995
# 2121              Rosemary Rees         1993
# 13604    Nancy Taylor Rosenberg         1998
# 9579   Angelo Solomon Rappoport         1995
# 14230              Val McDermid         2008
#
#                                             Publisher
# 16117                                  Vanguard Press
# 14                                        W.W. Norton
# 2606                           Ballantine Books, Inc.
# 16607                           Scribner Book Company
# 6444                              Spinsters Ink Books
# 12249            Westview Press/Arms and Armour Press
# 2615                                  Putnam Juvenile
# 8865                       Edinburgh University Press
# 9578                    Random House Value Publishing
# 16210                                            Hale
# 2121   Heinemann Educational Books - Primary Division
# 13604                                           Orion
# 9579                                     Senate Books
# 14230                        HarperCollins Publishers

# %% [markdown]
# # Combined recommendation system (content + weighted rating)
#
# So here were going to combine our content based recommendations with the weighted raiting scheme we cooked up earlier.

# %%
titles = samples[['Name', 'Authors', 'PublishYear', 'Publisher', "Rating", "RatingDistTotal"]]

def get_weighted_content_recommendations(title):
    try:
        # handle case in which book by same title is in dataset
        idx = indices[title][0]
    except IndexError:
        idx = indices[title]
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # get the top 40 recommendations
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:40]

    book_indices = [i[0] for i in sim_scores]
    books = titles.iloc[book_indices]

    # now sort by weighted rating
    ratings = books["Rating"]
    rating_count = books["RatingDistTotal"]
    MR = ratings.convert_dtypes(np.float16).mean()
    print("Mean Rating (MR) accross all books: ", MR)

    # relax to 75% quantile
    q = rating_count.quantile(.75)
    print("Minimum number of required ratings: ", q)
    
    books["wRating"] = books.apply(weighted_rating, axis=1)
    return books.sort_values(by="wRating", ascending=False)

# %%
index = 17136
title = samples.iloc[index].Name
desc = samples.iloc[index].Description
author = samples.iloc[index].Authors
year = samples.iloc[index].PublishYear
print("Title:", title, "\nDescription:", desc, "\nAuthor:", author, "\nYear:", year)
# Out:
# Title: Mathematics Made Simple
# Description: Brushing up on math has never been easier!Just about everyone can use some extra help improving or remembering basic math skills. Finally, all the information you need to master the basics, once and for all, is at your fingertips. Featuring several overviews of a multitude of mathematical concepts, as well as detailed learning plans, Mathematics Made Simple presents the information you need in clear, concise lessons that make math fun to study. Easy-to-use features include:* complete coverage of fractions, decimals, percents, algebra, linear equations, graphs, probability, geometry, and trigonometry* step-by-step solutions to every problem *multiple choice tests to help you monitor your progress * a final, comprehensive test that makes it easy to pinpoint your strengths and target areas that need work* glossaries of relevant mathematical terms* sidebars that introduce real-life applications of mathematical principlesVoid of lengthy explanations and difficult computations, Mathematics Made Simple will banish your math anxiety forever.
# Author: Thomas Cusick
# Year: 2003

# %%
get_weighted_content_recommendations(title)[:10]
# Out:
# Mean Rating (MR) accross all books:  3.32607171474359
# Minimum number of required ratings:  98.5
#                                                     Name  \
# 19866                          Linear Algebra Done Right
# 2386   Math For All Seasons: Mind-Stretching Math Rid...
# 17023  The Unexpected Hanging and Other Mathematical ...
# 19323                 Give Me Half! (Mathstart: Level 2)
# 15085                Life of Fred: Decimals and Percents
# 9285                                        Missing Math
# 7737       50 Mathematical Ideas You Really Need to Know
# 13757  Introductory Mathematical Analysis for Busines...
# 11869                            The Mission of Addition
# 534                 Introduction to Stochastic Processes
#
#                        Authors  PublishYear             Publisher    Rating  \
# 19866            Sheldon Axler         1997              Springer  4.308594
# 2386                 Greg Tang         2002      Scholastic Press  4.089844
# 17023           Martin Gardner         1986      Simon & Schuster  4.300781
# 19323         Stuart J. Murphy         1996      Turtleback Books  3.919922
# 15085       Stanley F. Schmidt         2007  Polka Dot Publishing  4.269531
# 9285              Loreen Leedy         2008             Two Lions  4.000000
# 7737               Tony Crilly         2007               Quercus  3.769531
# 13757  Ernest F. Haeussler Jr.         2007               Pearson  3.859375
# 11869          Brian P. Cleary         2005       Millbrook Press  3.869141
# 534          Gregory F. Lawler         2006             CRC Press  4.328125
#
#        RatingDistTotal   wRating
# 19866              815  3.744844
# 2386               421  3.738449
# 17023              112  3.736708
# 19323              319  3.736612
# 15085               85  3.736342
# 9285               161  3.736283
# 7737               977  3.736082
# 13757              147  3.735784
# 11869              119  3.735737
# 534                 21  3.735667

# %%
index = 18457
title = samples.iloc[index].Name
desc = samples.iloc[index].Description
author = samples.iloc[index].Authors
year = samples.iloc[index].PublishYear
print("Title:", title, "\nDescription:", desc, "\nAuthor:", author, "\nYear:", year)
# Out:
# Title: Superman/Batman, Vol. 7: The Search for Kryptonite
# Description: From Michael Green and Mike Johnson, two of the writers of the hit NBC TV series Heroes, comes this fast-paced new volume in the SUPERMAN/BATMAN series.The Man of Steel and the Dark Knight have decided that they must undertake the impossible task of recovering all the Kryptonite on Earth. But there are plenty of roadblocks in the way, as they realize that not everyone's willing to hand over the deadly substance. And one of those who's not ready to cooperate is none other than their fellow Justice League member, Aquaman.Collecting SUPERMAN/BATMAN #44-49.
# Author: Michael  Green
# Year: 2008

# %%
get_weighted_content_recommendations(title)[:10]
# Out:
# Mean Rating (MR) accross all books:  3.726862980769231
# Minimum number of required ratings:  529.0
#                                                    Name         Authors  \
# 11748                   Batman: The Dark Knight Returns    Frank Miller
# 7511                         Batman: The Long Halloween       Jeph Loeb
# 7103                                     Robin Year One     Chuck Dixon
# 16194                                      JLA/Avengers     Kurt Busiek
# 18201                                Superman: Brainiac     Geoff Johns
# 14795                           Batman: The Black Glove  Grant Morrison
# 8531           The Dark Knight (Dark Knight Trilogy #2)   Dennis O'Neil
# 6019   Justice League Of America Vol. 1: Tornado's Path    Brad Meltzer
# 11345              Justice League International, Vol. 3    Keith Giffen
# 15204               Booster Gold, Vol. 2: Blue and Gold     Geoff Johns
#
#        PublishYear         Publisher    Rating  RatingDistTotal   wRating
# 11748         2008        Paw Prints  4.261719           160749  4.139332
# 7511          1999  Turtleback Books  4.320312            75624  4.091177
# 7103          2008         DC Comics  4.039062             4566  3.761437
# 16194         2008         DC Comics  4.000000             3607  3.753655
# 18201         2009         DC Comics  4.019531             3101  3.752418
# 14795         2008         DC Comics  3.880859             4953  3.748837
# 8531          2008           Berkley  4.148438             1255  3.745786
# 6019          2008         DC Comics  3.849609             2091  3.740112
# 11345         2008         DC Comics  4.019531              535  3.738498
# 15204         2008         DC Comics  4.031250              474  3.738263

# %%
index = 10984
title = samples.iloc[index].Name
desc = samples.iloc[index].Description
author = samples.iloc[index].Authors
year = samples.iloc[index].PublishYear
print("Title:", title, "\nDescription:", desc, "\nAuthor:", author, "\nYear:", year)
# Out:
# Title: The Grave Tattoo
# Description: From bestselling author Val McDermid comes a modern thriller about an ancient murder set on the high seas…After summer rains uncover a corpse bearing tattoos like those of eighteenth-century seafarers, many residents of the English Lake District can’t help but wonder whether it’s the body of one of the town’s most legendary fugitives.Scholar and native Lakelander Jane Gresham feels compelled to finally discover the truth about the myths and buried secrets rooted in her hometown. What she never expected was to find herself at the heart of a 200-year-old mystery that still has the power to put lives on the line. And with each new lead she pursues, death follows hard on her heels….
# Author: Val McDermid
# Year: 2008

# %%
get_weighted_content_recommendations(title)[:10]
# Out:
# Mean Rating (MR) accross all books:  3.6829427083333335
# Minimum number of required ratings:  2418.5
#                                                     Name           Authors  \
# 5461                    Wanted (Pretty Little Liars, #8)      Sara Shepard
# 10204                 Chasing Darkness (Elvis Cole, #11)      Robert Crais
# 14230  Beneath The Bleeding (Tony Hill & Carol Jordan...      Val McDermid
# 2761                                           Old Filth       Jane Gardam
# 3469   A Thin Dark Line (Broussard and Fourcade #1, D...         Tami Hoag
# 8310            Ultimate Weapon (McClouds & Friends, #6)   Shannon McKenna
# 15453                       Runner (Jane Whitefield, #6)      Thomas Perry
# 18274                                  One Day at a Time    Danielle Steel
# 19105            Kindred Crimes (Jeri Howard Mystery #1)      Janet Dawson
# 10055                                          Lake News  Barbara Delinsky
#
#        PublishYear                  Publisher    Rating  RatingDistTotal  \
# 5461          2010                 HarperTeen  4.128906            41294
# 10204         2008         Wheeler Publishing  4.199219            15775
# 14230         2008   HarperCollins Publishers  4.109375             6771
# 2761          2004            Chatto & Windus  3.939453            13897
# 3469          1997                     Bantam  3.990234             8108
# 8310          2008                      Brava  4.148438             2220
# 15453         2009  Houghton Mifflin Harcourt  4.050781             2617
# 18274         2009            Delacorte Press  3.859375             6954
# 19105         1990         St. Martin's Press  4.199219             1088
# 10055         1999                   Headline  3.849609             4523
#
#         wRating
# 5461   3.915954
# 10204  3.848879
# 14230  3.781053
# 2761   3.780705
# 3469   3.771777
# 8310   3.753416
# 15453  3.751492
# 18274  3.750899
# 19105  3.745545
# 10055  3.745115

# %%
# comparison!
print("BASE CONTENT RECOMMENDATIONS")
print(get_content_recommendations(title)[:10])

print("\n\nWEIGHTED CONTENT RECOMMENDATIONS")
get_weighted_content_recommendations(title) # see all top 40 for ranking comparison
# Out:
# BASE CONTENT RECOMMENDATIONS
#                                                     Name  \
# 16117                                       Woman in Red
# 14     The Norton Anthology of English Literature, Vo...
# 2606   Japanese High Seas Fleet (Ballantine's Illustr...
# 16607                                         Death Drop
# 6444                     Crack Down (Kate Brannigan, #3)
# 12249  Red Navy at Sea: Soviet Naval Operations on th...
# 2615                                    He Saves the Day
# 8865   The Harvest of the Hills: Rural Life in Northe...
# 9578   Ancient Israel Myths & Legends 3 in 1 (Myths a...
# 16210                                    Dead Not Buried
#
#                         Authors  PublishYear  \
# 16117             Eileen Goudge         2008
# 14                  M.H. Abrams         2005
# 2606             Richard Humble         1973
# 16607                 B.M. Gill         1980
# 6444               Val McDermid         2002
# 12249           Bruce W. Watson         1982
# 2615              Marsha Hayles         2002
# 8865     Angus J. L. Winchester         2000
# 9578   Angelo Solomon Rappoport         1988
# 16210             Martin Beales         1995
#
#                                   Publisher    Rating  RatingDistTotal
# 16117                        Vanguard Press  3.800781             1886
# 14                              W.W. Norton  3.890625              499
# 2606                 Ballantine Books, Inc.  3.830078               30
# 16607                 Scribner Book Company  3.189453               21
# 6444                    Spinsters Ink Books  3.679688             1154
# 12249  Westview Press/Arms and Armour Press  4.000000                1
# 2615                        Putnam Juvenile  3.589844               34
# 8865             Edinburgh University Press  5.000000                3
# 9578          Random House Value Publishing  5.000000                1
# 16210                                  Hale  5.000000                3
#
#
# WEIGHTED CONTENT RECOMMENDATIONS
# Mean Rating (MR) accross all books:  3.6829427083333335
# Minimum number of required ratings:  2418.5
#                                                     Name  \
# 5461                    Wanted (Pretty Little Liars, #8)
# 10204                 Chasing Darkness (Elvis Cole, #11)
# 14230  Beneath The Bleeding (Tony Hill & Carol Jordan...
# 2761                                           Old Filth
# 3469   A Thin Dark Line (Broussard and Fourcade #1, D...
# 8310            Ultimate Weapon (McClouds & Friends, #6)
# 15453                       Runner (Jane Whitefield, #6)
# 18274                                  One Day at a Time
# 19105            Kindred Crimes (Jeri Howard Mystery #1)
# 10055                                          Lake News
# 2034   Underworld: The Mysterious Origins of Civiliza...
# 16117                                       Woman in Red
# 644                                      A Happy Meeting
# 17848                                     Thimble Summer
# 14     The Norton Anthology of English Literature, Vo...
# 13604                                     Abuse of Power
# 17182                                      All That Jazz
# 2760                        The People on Privilege Hill
# 14489                                         Lucky Jane
# 9579   Myths and Legends of Ancient Israel Volume 1 (...
# 16210                                    Dead Not Buried
# 8865   The Harvest of the Hills: Rural Life in Northe...
# 2606   Japanese High Seas Fleet (Ballantine's Illustr...
# 18678                                            Jubilee
# 5540                                The Door in the Lake
# 9578   Ancient Israel Myths & Legends 3 in 1 (Myths a...
# 12249  Red Navy at Sea: Soviet Naval Operations on th...
# 4387                               Pirates (Oxford Reds)
# 2121   Ships And Seafarers: Pupil Book (Heinemann Our...
# 1145   Weekends for Two in the Mid-Atlantic States: 5...
# 2724                                       Lavender Blue
# 2615                                    He Saves the Day
# 14551                                          The Curse
# 16607                                         Death Drop
# 7764                                        Beyond Magic
# 6444                     Crack Down (Kate Brannigan, #3)
# 1103                                  Dancing With Kings
# 4623                             Killing Moon (Moon, #1)
# 6575                                             Layover
#
#                         Authors  PublishYear  \
# 5461               Sara Shepard         2010
# 10204              Robert Crais         2008
# 14230              Val McDermid         2008
# 2761                Jane Gardam         2004
# 3469                  Tami Hoag         1997
# 8310            Shannon McKenna         2008
# 15453              Thomas Perry         2009
# 18274            Danielle Steel         2009
# 19105              Janet Dawson         1990
# 10055          Barbara Delinsky         1999
# 2034             Graham Hancock         2002
# 16117             Eileen Goudge         2008
# 644                 Betty Neels         2003
# 17848         Elizabeth Enright         2008
# 14                  M.H. Abrams         2005
# 13604    Nancy Taylor Rosenberg         1998
# 17182              Dee Williams         2008
# 2760                Jane Gardam         2007
# 14489               Delano Ames         1972
# 9579   Angelo Solomon Rappoport         1995
# 16210             Martin Beales         1995
# 8865     Angus J. L. Winchester         2000
# 2606             Richard Humble         1973
# 18678                 Jack Dann         2001
# 5540                Nancy Butts         2001
# 9578   Angelo Solomon Rappoport         1988
# 12249           Bruce W. Watson         1982
# 4387              Chris Powling         2003
# 2121              Rosemary Rees         1993
# 1145               Bill Gleeson         1998
# 2724         Parris Afton Bonds         1988
# 2615              Marsha Hayles         2002
# 14551             Carl Sherrell         1989
# 16607                 B.M. Gill         1980
# 7764              Susan Kearney         2008
# 6444               Val McDermid         2002
# 1103              Eva Stachniak         2010
# 4623               Rebecca York         2007
# 6575            David      Bell         2019
#
#                                             Publisher    Rating  \
# 5461                                       HarperTeen  4.128906
# 10204                              Wheeler Publishing  4.199219
# 14230                        HarperCollins Publishers  4.109375
# 2761                                  Chatto & Windus  3.939453
# 3469                                           Bantam  3.990234
# 8310                                            Brava  4.148438
# 15453                       Houghton Mifflin Harcourt  4.050781
# 18274                                 Delacorte Press  3.859375
# 19105                              St. Martin's Press  4.199219
# 10055                                        Headline  3.849609
# 2034                      Crown Publishing Group (NY)  3.960938
# 16117                                  Vanguard Press  3.800781
# 644                         Harlequin Readers' Choice  4.058594
# 17848                                     Square Fish  3.750000
# 14                                        W.W. Norton  3.890625
# 13604                                           Orion  3.810547
# 17182                                        Headline  4.089844
# 2760                                  Chatto & Windus  3.759766
# 14489                               Lythway Press Ltd  4.000000
# 9579                                     Senate Books  4.289062
# 16210                                            Hale  5.000000
# 8865                       Edinburgh University Press  5.000000
# 2606                           Ballantine Books, Inc.  3.830078
# 18678                                   HarperCollins  4.000000
# 5540                                  Collins Voyager  3.750000
# 9578                    Random House Value Publishing  5.000000
# 12249            Westview Press/Arms and Armour Press  4.000000
# 4387                                 Oxford Childrens  0.000000
# 2121   Heinemann Educational Books - Primary Division  0.000000
# 1145                             Chronicle Books (CA)  3.000000
# 2724                                          Fawcett  3.710938
# 2615                                  Putnam Juvenile  3.589844
# 14551                                   Pageant Books  2.830078
# 16607                           Scribner Book Company  3.189453
# 7764                           Tor Paranormal Romance  3.000000
# 6444                              Spinsters Ink Books  3.679688
# 1103                                    HarperCollins  3.310547
# 4623                                          Berkley  3.679688
# 6575                                    Berkley Books  3.179688
#
#        RatingDistTotal   wRating
# 5461             41294  3.915954
# 10204            15775  3.848879
# 14230             6771  3.781053
# 2761             13897  3.780705
# 3469              8108  3.771777
# 8310              2220  3.753416
# 15453             2617  3.751492
# 18274             6954  3.750899
# 19105             1088  3.745545
# 10055             4523  3.745115
# 2034              1334  3.741423
# 16117             1886  3.737848
# 644                363  3.737802
# 17848             7041  3.737254
# 14                 499  3.736985
# 13604              783  3.736600
# 17182              109  3.736203
# 2760               585  3.735700
# 14489               19  3.735514
# 9579                 7  3.735491
# 16210                3  3.735489
# 8865                 3  3.735489
# 2606                30  3.735470
# 18678                9  3.735460
# 5540               157  3.735458
# 9578                 1  3.735437
# 12249                1  3.735417
# 4387                 0  3.735411
# 2121                 0  3.735411
# 1145                 1  3.735396
# 2724               187  3.735318
# 2615                34  3.735310
# 14551               12  3.735188
# 16607               21  3.735176
# 7764                58  3.734537
# 6444              1154  3.734122
# 1103               193  3.733734
# 4623              1857  3.733365
# 6575              2849  3.704702

# %% [markdown]
# # Conclusion
#
# So above we can qualitatively see that our recommendations that include the weighted rating are better on average as they aren't suggesting books that have zero ratings (which are probably books that no-one has read).
#
# There is definetly a biased towards books that are most frequently reviewed, but that can be adjusted in the weighted rating if novelty is important for the recommenation system.
#
# Futher work could be done to include user rating data directly on a per user basis, but I will leave that as an exercise for the user.

# %% [markdown]
# # Hope you enjoyed!!
#
# Please feel free to use but be sure to link to any notebooks I got inspiration from (that I linked to)!
